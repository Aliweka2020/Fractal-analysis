# %%
import os 
import numpy as np
kernel = np.ones((3, 3), np.uint8) 
from skimage.morphology import skeletonize
import cv2
import matplotlib.pyplot as plt
from skimage import morphology

# %%
os.chdir(r'C:\Users\aweka\crop image normal\PA')

# %%
img1  =  cv2.imread('3 pa.tif')
plt.imshow(img1)

# %%
img2  =  img1.copy()

# %%
img2= cv2.GaussianBlur(img2 , (3,3),35)
plt.imshow(img2)

# %%
#result =  img2 -img1
#result = np.subtract(img2, img1)
result = np.subtract(img2, img1)
result2 = np.clip(img1.astype(np.int32) - img2, 0,65535).astype(np.uint16)
plt.imshow(result2)

# %%
result = result+128
plt.imshow(result)

# %%
_,result = cv2.threshold(result,127,255,cv2.THRESH_BINARY)
plt.imshow(result)

# %%
result = cv2.erode(result, kernel, iterations=1) 
plt.imshow(result)

# %%
result = cv2.dilate(result, kernel, iterations=1)
plt.imshow(result)

# %%
inv =  255- result 
plt.imshow(inv)

# %%
inv
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
inv =  255 - result 
skeleton = skeletonize(inv , method  ='lee')
plt.imshow(skeleton*255, cmap='gray')

# %%
j=1
for i in os.listdir(r'C:\Users\aweka\crop image normal\PA'):
    img1  =  cv2.imread(i,0)
    img2  =  img1
    img2= cv2.GaussianBlur(img2 , (3,3),33)
    result =  img2 -img1
    result = result+128
    _,result = cv2.threshold(result,127,255,cv2.THRESH_BINARY)
    result = cv2.erode(result, kernel, iterations=1) 
    result = cv2.dilate(result, kernel, iterations=1) 
    inv =  255- result 
    skeleton = skeletonize(inv , method  ='lee')
    cv2.imwrite(r'C:\Users\aweka\crop image normal\PA new\\' + str(j) + 'pa.png' , skeleton*255 )
    j = j+1
    fig = plt.figure()
    ax1 = fig.add_subplot(1,2,1)
    ax1.imshow(img1,cmap ='gray')
    ax2 = fig.add_subplot(1,2,2)
    ax2.imshow(skeleton, cmap= 'gray')
    #plt.imshow(img1,cmap ='gray')
    #plt.imshow(skeleton,cmap ='gray')

# %%
import porespy as ps
ps.visualization.set_mpl_style()
# Out:
# [13:57:23] ERROR    PARDISO solver not installed, run `pip install pypardiso`. Otherwise,          ]8;id=659870;file://C:\Users\aweka\anaconda3\Lib\site-packages\openpnm\utils\_workspace.py\_workspace.py]8;;\:]8;id=463459;file://C:\Users\aweka\anaconda3\Lib\site-packages\openpnm\utils\_workspace.py#56\56]8;;\
#                     simulations will be slow. Apple M chips not supported.

# %%
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
data.count
# Out:
# [113, 83, 57, 47, 35, 26, 20]

# %%
os.chdir(r'C:\Users\aweka\crop image stage III and VI\PA new')
for i in os.listdir(r'C:\Users\aweka\crop image stage III and VI\PA new'):
    img =  cv2.imread(i)
    data = ps.metrics.boxcount(img)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_xlabel('box edge length')
    ax1.set_ylabel('number of boxes spanning phases')
    ax2.set_xlabel('box edge length')
    ax2.set_ylabel('slope')
    ax2.set_xscale('log')
    ax1.plot(data.size, data.count,'-o')
    ax2.plot(data.size, data.slope,'-o');
    fig.savefig( r'C:\Users\aweka\crop image stage III and VI\PA fractal\\' + str(i)+'pa.png')
    plt.close(fig)
# Out:
# ...
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
from FractalDimension import fractal_dimension

# %%
img =  cv2.imread('9pa.png',0)

# %%
fd = fractal_dimension(img)
print(f"Fractal dimension of the image: {fd}")
# Out:
# Fractal dimension of the image: 2.907828085771197
